# %%
import pandas as pd
import json
from datetime import date
import datetime

import numpy as np
from dateutil.parser import parse

# %%
comp_returns_list=["1 Month","3 Months","6 Months","1 Year","2 Years","3 Years","4 years","5 Years"]

comp_returns={"1 Month":30,
"3 Months": 90,
"6 Months":180,
"1 Year" : 365,
"2 Years" :730,
"3 Years" : 1095,
"4 years" : 1460,
"5 Years":1825
}


compareinfo=["Sector","Market Cap","P/E Ratio","Dividend Yield"]

returns={"6 Months":180,
         "1 Year" : 365,
         "3 Year" : 1095,
         "4 year" : 1400,
}

up='fa fa-level-up c-red-500'
down='fa fa-level-down c-red-500'

# %%
path='/Users/hemanth/Desktop/test2/static/socgen/'
df=pd.read_csv(path+'data.csv')

# %%
df['date']=pd.to_datetime(df['date']).dt.date
df=df.sort_values('date',ascending=False)

# %%
df.date=pd.to_datetime(df.date).dt.strftime('%d-%b-%Y')
df["tooltext"]="<b>"+df["date"]+"<br>Open: <b>$openDataValue</b><br>Close: <b>$closeDataValue</b><br>High: <b>$highDataValue</b><br>Low: <b>$lowDataValue</b><br>Volume: <b>$volumeDataValue</b>"

# %%
def get_ind(duration, symbol):
    data = df[df["symbol"] == symbol]
    data = data.reset_index(drop=True)
    
    
    end_date=data["date"].iloc[-1]
    end_date = parse(end_date)
    end_date=end_date.date()
    ind = []
    while (len(ind) == 0):
        to_date = date(2016, 12, 30) - datetime.timedelta(days=duration)
        if(end_date>to_date):
            to_date=end_date
        to_date = to_date.strftime('%d-%b-%Y')
        ind = data[data["date"] == to_date].index
        duration += 1
        
        

    ind = ind[0]

    data = data[0:ind]
    data = data.iloc[::-1]
    data = data.reset_index(drop=True)
    data = data.reset_index()

    
    data.columns = ["x", "label", "symbol", "open", "close", "low", "high", "volume", "tooltext"]
    
    return data

# %%
def get_json(duration, symbol):
    
    data=get_ind(duration, symbol)
    
    label_skip = int(len(data)/7)

    cat = data.iloc[::label_skip, :]
    cat=cat[["x","label"]]

    cat_json = cat.to_json(orient="records")

    dataset = data[["x", "open", "close", "low", "high", "volume", "tooltext"]]
    dataset_json = dataset.to_json(orient="records")

    return cat_json, dataset_json

# %%
def get_allcompanies(pd_df):
    pd_df = pd_df.reset_index(drop=True)
    df2 = pd_df[pd_df["date"] == pd_df["date"][501]]
    df1 = pd_df[pd_df["date"] == pd_df["date"][0]]
    df2 = df2.rename(columns={"close": "prev_close"})
    data = pd.merge(df1, df2[["symbol", "prev_close"]], on=["symbol"], how="left")
    data['change'] = data["close"] - data["prev_close"]
    data['per_change'] = (data['change'] / data['close']) * 100
    data[['open','close','low','high','prev_close','change',"per_change"]]=data[['open','close','low','high','prev_close','change',"per_change"]].round(2)
    return data

def comapany_list_data(data,sector,subsector):
    
    if(sector=="ALL"):
        return data

    elif(subsector=="ALL"):
        data=data[data["Sector"]==sector]
    else:
        data=data[data["GICS Sub Industry"]==subsector]
        
    data.reset_index(drop=True,inplace=True)
    
    return data

def company_list(sector,subsector):
    data = get_allcompanies(df)
    data=data.rename(columns={"symbol":"Symbol"})
    data=pd.merge(data,tickers[["Symbol","Sector","GICS Sub Industry"]],on=["Symbol"],how="left")
    
    data=comapany_list_data(data,sector,subsector)

    company_render = ""
    for i in range(len(data)):
        company_render += "<tr>"
        company_render += "<td><a href='/index?company_name="+str(data["Symbol"].iloc[i])+"""'>""" + str(data["Symbol"].iloc[i]) + "</a></td>"
        company_render += "<td>" + str(data["close"].iloc[i]) + "</td>"
        company_render += "<td>" + str(data["change"].iloc[i]) + "</td>"
        company_render += "<td>" + str(data["per_change"].iloc[i]) + "</td>"
        company_render += "<td>" + str(data["open"].iloc[i]) + "</td>"
        company_render += "<td>" + str(data["high"].iloc[i]) + "</td>"
        company_render += "<td>" + str(data["low"].iloc[i]) + "</td>"
        company_render += "<td>" + str(data["prev_close"].iloc[i]) + "</td>"
        company_render += '</tr>'

    return company_render

# %%
def get_x_compare(duration, symbol):

    data=get_ind(duration, symbol)
    
    
    cat=data[["x","label"]]
    labelstep=int(len(cat)/7)
    cat_json = cat.to_json(orient="records")

    return cat_json,labelstep

# %%
def get_company_series(duration, symbol,if_return):
    
    data=get_ind(duration, symbol)
    
    
    high=np.max(data["high"]).round(2)
    low=np.min(data["low"]).round(2)
    
    data = data[["x", "label", "symbol", "close"]]
    data["start"] = data["close"][0]
    data["return"] = ((data["close"] - data["start"]) / data["start"]).round(2)
    data["return"]=(data["return"]*100).round(2)
    
    if(if_return==1):
        return data["return"].iloc[-1]
    
    if(if_return==2):
        return data["return"].iloc[-1],high,low
    
    dataset = data[["x", "return"]]
    dataset.columns = ["x", "value"]
    
    dataset_json = dataset.to_json(orient="records")

    series = {}
    series["seriesname"] = symbol
    series["data"] = json.loads(dataset_json)
    return series

# %%
def get_series(duration,companies):
    series_dataset=[]
    for i in companies:
        series_dataset.append(get_company_series(duration,i,0))
        
    series_dataset=json.dumps(series_dataset)
    
    return series_dataset

# %%
companies=["FB","GOOGL","AAPL"]

# %%
def get_compare_table(companies):
    
    head="<thead><tr><th>index</th>"
    for i in companies:
        head+="<th>"+i+"</th>"
    head+="</tr></thead>"
    
    comp_return={}
    for i in returns.keys():
        ret=[]
        for j in companies:
            ret.append(get_company_series(returns[i],j,1).round(1))

        comp_return[i]=ret
        
    body="<tbody>"
    for i in comp_return.keys():
        body+="<tr><td>"+i+"</td>"
        for j in comp_return[i]:
            if(j>0):
                color="green"
            else:
                color="red"
            
            body+="<td><font color='"+color+"'>"+str(j)+"%</font></td>"

        body+="</tr>"
    body+="</tbody>"
    
    return head+body

# %%
def get_return_table(symbol):
    body=""
    for i in range(0,len(comp_returns_list),2):
        body+="<tr>"
        body+="<td>"+comp_returns_list[i]+"</td>"
        a=get_company_series(comp_returns[comp_returns_list[i]],symbol,1).round(1)
        arrow=""
        if(a>0):
            arrow=up
            color="green"
        else:
            arrow=down
            color="red"
            
        body+="<td><font color='"+color+"'>"+str(np.abs(a))+" %<i class='"+arrow+"'></i></font></td>"
        
        body+="<td>"+comp_returns_list[i+1]+"</td>"
        a=get_company_series(comp_returns[comp_returns_list[i+1]],symbol,1)
        arrow=""
        if(a>0):
            arrow=up
            color="green"
        else:
            arrow=down
            color="red"
        body+="<td><font color='"+color+"'>"+str(np.abs(a))+" %<i class='"+arrow+"'></i></font></td>"

        body+="</tr>"
    
    return body

# %%
def get_scroll_bar():
    data=get_allcompanies(df)
    data=data[["symbol","close","change"]]
    
    body=""
    for i in range(len(data)):
        body+="<div class='scroll'>"
        body+="<a href='/index?company_name="+str(data["symbol"].iloc[i])+"""'>"""
        body+='<div class="stat-heading">'+str(data["symbol"].iloc[i])+'</div>'

        if(data["change"].iloc[i]>0):
            arrow="pe-7s-angle-up"
            color="green"
        else:
            arrow="pe-7s-angle-down"
            color="red"

        body+="<div class='stat-text'><span>"+str(data["close"].iloc[i])
        body+="<i class='"+arrow+"'></i>"
        body+="<font color='"+color+"'style='font-size: 0.8em;'>"+ str(data["change"].iloc[i]) +"</font></span></div>"       
        body+="</a></div> "
        
    return body

# %%
tickers=pd.read_csv(path+"tickers.csv")
tickers["Market Cap ($M)"]=(tickers["Market Cap ($M)"]/1000).round(2)
tickers["P/E Ratio"]=(tickers["P/E Ratio"]).round(2)
tickers["Dividend Yield"]=(tickers["Dividend Yield"]).round(4)

tickers=tickers.rename(columns={"GICS Sector":"Sector",'Market Cap ($M)':"Market Cap"})

# %%
tickers=tickers[tickers["Symbol"].isin(df['symbol'])]
tickers["GICS Sub Industry"]=tickers["GICS Sub Industry"].str.replace('& ',',')
tickers.reset_index(drop=True,inplace=True)

# %%
def get_name(symbol):
    ind=tickers[tickers["Symbol"]==symbol].index
    if(len(ind)==0):
        return symbol
    return tickers.at[ind[0],"Security"]

# %%
def get_Companyinfo(symbol):
    ind=tickers[tickers["Symbol"]==symbol].index
    
    if(len(ind)==0):
        ind=[134]
    
    body="<tr><td>Sector</td><td>"
    body+=str(tickers["Sector"].iloc[ind[0]])
    body+='</td></tr><tr><td>Market Cap</td><td>$ '
    body+=str(tickers["Market Cap"].iloc[ind[0]])
    body+='B</td></tr><tr><td>P/E Ratio</td><td>'
    body+=str(tickers["P/E Ratio"].iloc[ind[0]])
    body+='</td></tr><tr><td>Dividend Yield</td><td>'
    body+=str(tickers["Dividend Yield"].iloc[ind[0]])
    body+='</td></tr>'
    
    return body

# %%
# Out:
#                           Security Symbol                  Sector  \
# 0                       3M Company    MMM             Industrials
# 1              Abbott Laboratories    ABT             Health Care
# 2                      AbbVie Inc.   ABBV             Health Care
# 4                    Accenture plc    ACN  Information Technology
# 5              Activision Blizzard   ATVI  Communication Services
# 6                Adobe Systems Inc   ADBE  Information Technology
# 8               Advance Auto Parts    AAP  Consumer Discretionary
# 9                         AES Corp    AES               Utilities
# 10   Affiliated Managers Group Inc    AMG              Financials
# 11                       AFLAC Inc    AFL              Financials
# 12        Agilent Technologies Inc      A             Health Care
# 13    Air Products & Chemicals Inc    APD               Materials
# 14         Akamai Technologies Inc   AKAM  Information Technology
# 15            Alaska Air Group Inc    ALK             Industrials
# 16                  Albemarle Corp    ALB               Materials
# 18         Alexion Pharmaceuticals   ALXN             Health Care
# 20                        Allegion   ALLE             Industrials
# 21                   Allergan, Plc    AGN             Health Care
# 22           Alliance Data Systems    ADS  Information Technology
# 23             Alliant Energy Corp    LNT               Utilities
# 24                   Allstate Corp    ALL              Financials
# 25            Alphabet Inc Class A  GOOGL  Communication Services
# 26            Alphabet Inc Class C   GOOG  Communication Services
# 27                Altria Group Inc     MO        Consumer Staples
# 28                 Amazon.com Inc.   AMZN  Consumer Discretionary
# 29                     Ameren Corp    AEE               Utilities
# 30         American Airlines Group    AAL             Industrials
# 31         American Electric Power    AEP               Utilities
# 32             American Express Co    AXP              Financials
# 33    American International Group    AIG              Financials
# ..                             ...    ...                     ...
# 473               Verisk Analytics   VRSK             Industrials
# 474         Verizon Communications     VZ  Communication Services
# 475     Vertex Pharmaceuticals Inc   VRTX             Health Care
# 476                    Viacom Inc.   VIAB  Communication Services
# 477                      Visa Inc.      V  Information Technology
# 478           Vornado Realty Trust    VNO             Real Estate
# 479               Vulcan Materials    VMC               Materials
# 480                        Walmart    WMT        Consumer Staples
# 481       Walgreens Boots Alliance    WBA        Consumer Staples
# 482        The Walt Disney Company    DIS  Communication Services
# 483          Waste Management Inc.     WM             Industrials
# 484             Waters Corporation    WAT             Health Care
# 485           Wec Energy Group Inc    WEC               Utilities
# 487                    Wells Fargo    WFC              Financials
# 489                Western Digital    WDC  Information Technology
# 490               Western Union Co     WU  Information Technology
# 491                       WestRock    WRK               Materials
# 492                   Weyerhaeuser     WY             Real Estate
# 493                Whirlpool Corp.    WHR  Consumer Discretionary
# 494                  Williams Cos.    WMB                  Energy
# 495           Willis Towers Watson   WLTW              Financials
# 496               Wynn Resorts Ltd   WYNN  Consumer Discretionary
# 497                Xcel Energy Inc    XEL               Utilities
# 498                          Xerox    XRX  Information Technology
# 499                         Xilinx   XLNX  Information Technology
# 500                     Xylem Inc.    XYL             Industrials
# 501                Yum! Brands Inc    YUM  Consumer Discretionary
# 502         Zimmer Biomet Holdings    ZBH             Health Care
# 503                  Zions Bancorp   ZION              Financials
# 504                         Zoetis    ZTS             Health Care
#
#                                GICS Sub Industry  Dividend Yield  Market Cap  \
# 0                       Industrial Conglomerates          0.0278      114.07
# 1                          Health Care Equipment          0.0180      124.96
# 2                                Pharmaceuticals          0.0531      121.15
# 4                  IT Consulting ,Other Services          0.0192       97.00
# 5                 Interactive Home Entertainment          0.0071       36.47
# 6                           Application Software          0.0000      119.57
# 8                              Automotive Retail          0.0016       11.17
# 9    Independent Power Producers ,Energy Traders          0.0344       10.52
# 10               Asset Management ,Custody Banks          0.0109        5.77
# 11                        Life ,Health Insurance          0.0219       36.21
# 12                         Health Care Equipment          0.0089       23.46
# 13                              Industrial Gases          0.0288       35.33
# 14             Internet Services ,Infrastructure          0.0000       10.66
# 15                                      Airlines          0.0221        7.83
# 16                           Specialty Chemicals          0.0175        8.13
# 18                                 Biotechnology          0.0000       27.09
# 20                             Building Products          0.0100        8.00
# 21                               Pharmaceuticals          0.0184       54.19
# 22          Data Processing ,Outsourced Services          0.0128        9.68
# 23                            Electric Utilities          0.0329       10.17
# 24                  Property ,Casualty Insurance          0.0214       29.67
# 25                   Interactive Media ,Services          0.0000      766.06
# 26                   Interactive Media ,Services          0.0000      758.75
# 27                                       Tobacco          0.0723       83.13
# 28             Internet ,Direct Marketing Retail          0.0000      816.86
# 29                               Multi-Utilities          0.0280       16.60
# 30                                      Airlines          0.0114       16.11
# 31                            Electric Utilities          0.0349       37.87
# 32                              Consumer Finance          0.0155       86.08
# 33                  Property ,Casualty Insurance          0.0296       38.20
# ..                                           ...             ...         ...
# 473                Research ,Consulting Services          0.0000       19.30
# 474        Integrated Telecommunication Services          0.0427      233.05
# 475                                Biotechnology          0.0000       48.43
# 476                        Movies ,Entertainment          0.0276       10.07
# 477                  Internet Software ,Services          0.0072      315.03
# 478                                 Office REITs          0.0399       12.60
# 479                       Construction Materials          0.0111       13.31
# 480                  Hypermarkets ,Super Centers          0.0215      281.64
# 481                                  Drug Retail          0.0245       67.82
# 482                        Movies ,Entertainment          0.0158      165.60
# 483           Environmental ,Facilities Services          0.0196       40.46
# 484                     Health Care Distributors          0.0000       17.36
# 485                           Electric Utilities          0.0332       22.41
# 487                            Diversified Banks          0.0359      229.66
# 489    Technology Hardware, Storage ,Peripherals          0.0463       12.49
# 490                  Internet Software ,Services          0.0417        8.07
# 491                              Paper Packaging          0.0430       10.85
# 492                            Specialized REITs          0.0529       19.25
# 493                         Household Appliances          0.0368        7.98
# 494             Oil ,Gas Storage ,Transportation          0.0510       32.29
# 495                            Insurance Brokers          0.0151       20.62
# 496                              Casinos ,Gaming          0.0253       12.89
# 497                              Multi-Utilities          0.0301       25.98
# 498    Technology Hardware, Storage ,Peripherals          0.0407        5.85
# 499                               Semiconductors          0.0130       27.93
# 500                         Industrial Machinery          0.0120       12.55
# 501                                  Restaurants          0.0155       28.95
# 502                        Health Care Equipment          0.0089       21.91
# 503                               Regional Banks          0.0247        9.13
# 504                              Pharmaceuticals          0.0077       40.69
#
#      P/E Ratio
# 0        19.71
# 1        24.22
# 2         9.90
# 4        22.44
# 5        20.84
# 6        43.55
# 8        22.89
# 9        12.09
# 10        6.97
# 11       11.99
# 12       26.06
# 13       21.49
# 14       27.71
# 15       14.53
# 16       14.47
# 18       17.99
# 20       19.12
# 21        9.09
# 22        8.42
# 23       20.22
# 24        9.71
# 25       24.36
# 26       30.81
# 27       11.26
# 28      100.16
# 29       19.51
# 30        7.90
# 31       19.51
# 32       13.66
# 33       18.44
# ..         ...
# 473      29.91
# 474      12.50
# 475      83.72
# 476       7.08
# 477      29.62
# 478      16.75
# 479      26.76
# 480      21.88
# 481      11.73
# 482      15.60
# 483      24.14
# 484      27.45
# 485      20.82
# 487      10.91
# 489       3.21
# 490       9.89
# 491      10.18
# 492      18.39
# 493       8.59
# 494      32.92
# 495      19.84
# 496      17.08
# 497      20.45
# 498       7.20
# 499      40.10
# 500      24.94
# 501      24.80
# 502      14.06
# 503      11.86
# 504      27.49
#
# [441 rows x 7 columns]

# %%
def get_Compareinfo(symbol,col):
    ind=tickers[tickers["Symbol"]==symbol].index
    
    if(len(ind)==0):
        ind=[134]
    
    return tickers[col].iloc[ind[0]]


def get_compare_info_table(companies):
    
    head="<thead><tr><th>index</th>"
    for i in companies:
        head+="<th>"+i+"</th>"
    head+="</tr></thead>"
    
    comp_return={}
    for i in compareinfo:
        ret=[]
        for j in companies:
            print(j)
            ret.append(get_Compareinfo(j,i))

        comp_return[i]=ret
        
    print(comp_return)
        
    body="<tbody>"
    for i in comp_return.keys():
        body+="<tr><td>"+i+"</td>"
        for j in comp_return[i]:
            body+="<td>"+str(j)+"</td>"

        body+="</tr>"
    body+="</tbody>"
    
    return head+body

# %%
def get_sector(sector):
    
    if(sector=="ALL"):
        sector="Sector"
    
    sectors=list(tickers["Sector"])
    sectors=list(set(sectors))
    sectors=["ALL"]+sectors
    
    body='<button class="btn btn-secondary dropdown-toggle" type="button" id="dropdownMenu" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">'
    body+=sector
    body+="</button><div class='dropdown-menu' aria-labelledby='dropdownMenu'>"
    for i in sectors:
        body+='<a class="dropdown-item" href="/companies?sector='+str(i)+'">'+str(i)+'</a>'

    body+="</div>"
    
    
    return body

# %%
def get_subsector(sector,subplace):
    
    if(sector=="ALL"):
        subplace="Sub Sector"
        subsectors=["ALL"]
        
        
    else:
        subsectors=list(tickers[tickers["Sector"]==sector]["GICS Sub Industry"])
        subsectors=list(set(subsectors))
        subsectors=["ALL"]+subsectors
       
    if(subplace=="ALL"):
        subplace="Sub Sector"

    body='<button class="btn btn-secondary dropdown-toggle" type="button" id="dropdownMenu" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">'
    body+=subplace
    body+="</button><div class='dropdown-menu' aria-labelledby='dropdownMenu'>"
    for i in subsectors:
        body+='<a class="dropdown-item" href="/companies?subsector='+str(i)+'">'+str(i)+'</a>'

    body+="</div>"
    
    return body

# %%
def check_company(company):
    return pd.Series(company).isin(df["symbol"])[0]

# %%
check_company("FB")
# Out:
# True

# %%
ticker["sector"]
.iloc[]
